# %%
import pandas as pd
import tiktoken
from openai.embeddings_utils import get_embedding
import openai
import os
from dotenv import load_dotenv
load_dotenv('../.env')
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
df = pd.read_json('./enneads.json')

# %%
df.head()
# Out:
#         enneadTitle    tractateTitle sectionTitle  \
# 0  THE FIRST ENNEAD  FIRST TRACTATE.    Section 1
# 1  THE FIRST ENNEAD  FIRST TRACTATE.    Section 2
# 2  THE FIRST ENNEAD  FIRST TRACTATE.    Section 3
# 3  THE FIRST ENNEAD  FIRST TRACTATE.    Section 4
# 4  THE FIRST ENNEAD  FIRST TRACTATE.    Section 5
#
#                                                lines
# 0  Section 1 \n 1. Pleasure and distress, fear an...
# 1  Section 2 \n 2. This first enquiry obliges us ...
# 2  Section 3 \n 3. We may treat of the Soul as in...
# 3  Section 4 \n 4. Let us consider, then, the hyp...
# 4  Section 5 \n 5. Now this Animate might be mere...

# %%
df["combined"] = (
    "Plotinus:\n" + df.enneadTitle.str.strip() + "\nTractate Title: " + df.tractateTitle.str.strip() 
    # add sectionTitle and lines
    + "\n" + df.lines.str.strip()
)

# %%
df.head()
# Out:
#         enneadTitle    tractateTitle sectionTitle  \
# 0  THE FIRST ENNEAD  FIRST TRACTATE.    Section 1
# 1  THE FIRST ENNEAD  FIRST TRACTATE.    Section 2
# 2  THE FIRST ENNEAD  FIRST TRACTATE.    Section 3
# 3  THE FIRST ENNEAD  FIRST TRACTATE.    Section 4
# 4  THE FIRST ENNEAD  FIRST TRACTATE.    Section 5
#
#                                                lines  \
# 0  Section 1 \n 1. Pleasure and distress, fear an...
# 1  Section 2 \n 2. This first enquiry obliges us ...
# 2  Section 3 \n 3. We may treat of the Soul as in...
# 3  Section 4 \n 4. Let us consider, then, the hyp...
# 4  Section 5 \n 5. Now this Animate might be mere...
#
#                                             combined
# 0  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...
# 1  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...
# 2  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...
# 3  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...
# 4  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
# subsample to 1k most recent reviews and remove samples that are too long
top_n = 1000

encoding = tiktoken.get_encoding(embedding_encoding)

# omit reviews that are too long to embed
df["n_tokens"] = df.combined.apply(lambda x: len(encoding.encode(x)))
without_too_long = df[df.n_tokens <= max_tokens].tail(top_n)

# %%
first_ennead = df[df.enneadTitle == "THE FIRST ENNEAD"].head()
first_ennead
# Out:
#         enneadTitle    tractateTitle sectionTitle  \
# 0  THE FIRST ENNEAD  FIRST TRACTATE.    Section 1
# 1  THE FIRST ENNEAD  FIRST TRACTATE.    Section 2
# 2  THE FIRST ENNEAD  FIRST TRACTATE.    Section 3
# 3  THE FIRST ENNEAD  FIRST TRACTATE.    Section 4
# 4  THE FIRST ENNEAD  FIRST TRACTATE.    Section 5
#
#                                                lines  \
# 0  Section 1 \n 1. Pleasure and distress, fear an...
# 1  Section 2 \n 2. This first enquiry obliges us ...
# 2  Section 3 \n 3. We may treat of the Soul as in...
# 3  Section 4 \n 4. Let us consider, then, the hyp...
# 4  Section 5 \n 5. Now this Animate might be mere...
#
#                                             combined  n_tokens
# 0  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       254
# 1  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       589
# 2  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       459
# 3  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       618
# 4  Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       674

# %%
df["embedding"] = df.combined.apply(lambda x: get_embedding(x, engine=embedding_model))
df.to_json("embeddings.json")

# %%
df.head()
# Out:
#           enneadTitle    tractateTitle sectionTitle  \
# 0    THE FIRST ENNEAD  FIRST TRACTATE.    Section 1
# 1    THE FIRST ENNEAD  FIRST TRACTATE.    Section 2
# 2    THE FIRST ENNEAD  FIRST TRACTATE.    Section 3
# 3    THE FIRST ENNEAD  FIRST TRACTATE.    Section 4
# 4    THE FIRST ENNEAD  FIRST TRACTATE.    Section 5
# ..                ...              ...          ...
# 647  THE SIXTH ENNEAD  NINTH TRACTATE.    Section 6
# 648  THE SIXTH ENNEAD  NINTH TRACTATE.    Section 7
# 649  THE SIXTH ENNEAD  NINTH TRACTATE.    Section 8
# 650  THE SIXTH ENNEAD  NINTH TRACTATE.    Section 9
# 651  THE SIXTH ENNEAD  NINTH TRACTATE.   Section 10
#
#                                                  lines  \
# 0    Section 1 \n 1. Pleasure and distress, fear an...
# 1    Section 2 \n 2. This first enquiry obliges us ...
# 2    Section 3 \n 3. We may treat of the Soul as in...
# 3    Section 4 \n 4. Let us consider, then, the hyp...
# 4    Section 5 \n 5. Now this Animate might be mere...
# ..                                                 ...
# 647  Section 6 \n 6. In what sense, then, do we ass...
# 648  Section 7 \n 7. If the mind reels before somet...
# 649  Section 8 \n 8. Every soul that knows its hist...
# 650  Section 9 \n 9. In this choiring, the soul loo...
# 651  Section 10 \n 10. But how comes the soul not t...
#
#                                               combined  n_tokens  \
# 0    Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       254
# 1    Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       589
# 2    Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       459
# 3    Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       618
# 4    Plotinus:\nTHE FIRST ENNEAD\nTractate Title: F...       674
# ..                                                 ...       ...
# 647  Plotinus:\nTHE SIXTH ENNEAD\nTractate Title: N...       936
# 648  Plotinus:\nTHE SIXTH ENNEAD\nTractate Title: N...       468
# 649  Plotinus:\nTHE SIXTH ENNEAD\nTractate Title: N...       667
# 650  Plotinus:\nTHE SIXTH ENNEAD\nTractate Title: N...       926
# 651  Plotinus:\nTHE SIXTH ENNEAD\nTractate Title: N...       386
#
#                                              embedding
# 0    [-0.005241681821644306, -0.011729962192475796,...
# 1    [-0.004125811625272036, 0.0019692867062985897,...
# 2    [-0.010390679351985455, -0.0018806734587997198...
# 3    [-0.010853996500372887, -0.007171030156314373,...
# 4    [-0.017799487337470055, -0.0033750722650438547...
# ..                                                 ...
# 647  [-0.005158691667020321, 0.016849299892783165, ...
# 648  [0.009452428668737411, -0.001767597277648747, ...
# 649  [-0.001969702076166868, 0.0037387553602457047,...
# 650  [-0.0009392640204168856, -0.000636529468465596...
# 651  [0.0023516444489359856, -0.005092182662338018,...
#
# [652 rows x 7 columns]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib
import numpy as np


datafile_path = "./embeddings.json"
from_json = pd.read_csv(datafile_path).sample(50)

# Convert to a list of lists of floats
matrix = np.array(from_json.embedding.apply(eval).to_list())

# Create a t-SNE model and transform the data
tsne = TSNE(n_components=2, perplexity=15, random_state=42, init='random', learning_rate=200)
vis_dims = tsne.fit_transform(matrix)
vis_dims.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 8
#       4 import numpy as np
#       7 datafile_path = "./embeddings.json"
# ----> 8 from_json = pd.read_csv(datafile_path).sample(50)
#      10 # Convert to a list of lists of floats
#      11 matrix = np.array(from_json.embedding.apply(eval).to_list())
#
# File ~/.pyenv/transformer/lib/python3.10/site-packages/pandas/core/generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~/.pyenv/transformer/lib/python3.10/site-packages/pandas/core/sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# --> 150 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151     np.intp, copy=False
#     152 )
#
# File mtrand.pyx:909, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken
